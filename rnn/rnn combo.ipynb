# %%
import numpy as np
import pandas as pd
import re
from keras.preprocessing.text import Tokenizer
from sklearn.utils import shuffle
from matplotlib import pyplot as plt
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout, Embedding, Masking, Bidirectional
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
lem = WordNetLemmatizer()
RANDOM_STATE = 50
UNK_ID = 1
PAD_ID = 0
MAX_LEN = 20
# Out:
# 2022-05-13 12:37:43.210590: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-13 12:37:43.210619: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/vaibhav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/vaibhav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/vaibhav/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/vaibhav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def format_sequence(s):
    s =  re.sub(r'(?<=[^\s0-9])(?=[.,;?])', r' ', s)
    s = re.sub(r'\((\d+)\)', r'', s)
    s = re.sub(r'\s\s', ' ', s)
    s = re.sub(r"[^A-Za-z0-9(),!?\'`]", " ", s)
    s = re.sub(r"\'s", " \'s", s)
    s = re.sub(r"\'ve", " \'ve", s)
    s = re.sub(r"n\'t", " n\'t", s)
    s = re.sub(r"\'re", " \'re", s)
    s = re.sub(r"\'d", " \'d", s)
    s = re.sub(r"\'ll", " \'ll", s)
    s = re.sub(r",", " , ", s)
    s = re.sub(r"!", " ! ", s)
    s = re.sub(r"\"", " \" ", s)
    s = re.sub(r"\(", " ( ", s)
    s = re.sub(r"\)", " ) ", s)
    s = re.sub(r"\?", " ? ", s)
    s = re.sub(r"\s{2,}", " ", s)
    s = re.sub(r"\.", " . ", s)
    s = re.sub(r"., ", " , ", s)
    s = re.sub(r"\\n", " ", s)
    return s.strip().lower()

def make_sequences(arr,lower=True,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'):
    tokenizer = Tokenizer(lower=lower, filters=filters)
    tokenizer.fit_on_texts(arr)

    word_idx = tokenizer.word_index
    idx_word = tokenizer.index_word
    num_words = len(word_idx) + 1
    word_counts = tokenizer.word_counts

    features = tokenizer.texts_to_sequences(arr)
    
    print(f'There are {len(features)} sequences.')

    features = np.array(features)

    return word_idx,idx_word,num_words,word_counts,features

def create_train_valid(features,labels,num_words,train_fraction = 0.7,max_valid=70):

    # features,labels = shuffle(features,labels,random_state = RANDOM_STATE)

    train_end = max(int(train_fraction*len(labels)),len(labels)-max_valid)

    train_features = np.asarray(features[:train_end])
    valid_features = np.asarray(features[train_end:])

    train_labels = np.asarray(labels[:train_end])
    valid_labels = np.asarray(labels[train_end:])
    
    return train_features,valid_features,train_labels,valid_labels

# %%
data = pd.read_csv('../datasets/sarcasm_data.csv').dropna(axis=0,how='any')
# print(data.columns)
data['text'].str.replace('[^a-zA-Z]', ' ')

text = [format_sequence(a) for a in data['text'].to_list()]
labels = data['sarcasm'].to_list()

lower = False
filters = '!"%;[\\]^_`{|}~\t\n'

word_idx,idx_word,num_words,word_counts,features = make_sequences(text,lower,filters)
X_train, X_valid, y_train, y_valid = create_train_valid(features,labels,num_words,train_fraction=0.9)
training_dict = {'X_train': X_train, 'X_valid': X_valid,'y_train': y_train, 'y_valid': y_valid}
# Out:
# There are 690 sequences.
# /tmp/ipykernel_32845/1559495250.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['text'].str.replace('[^a-zA-Z]', ' ')
# /tmp/ipykernel_32845/3068253009.py:37: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(features)

# %%
glove_loc = '../glove.6B.100d.txt'
glove = np.loadtxt(glove_loc,dtype='str',comments=None)

vectors = glove[:,1:].astype('float')
words = glove[:,0]

del glove

# %%
word_lookup = {word:vector for word,vector in zip(words,vectors)}

embedding_matrix = np.zeros((num_words, vectors.shape[1]))

not_found = 0

for i,word in enumerate(word_idx.keys()):
    vector = word_lookup.get(word,None)

    if vector is not None:
        embedding_matrix[i+1,:] = vector
    else:
        not_found +=1

embedding_matrix = np.nan_to_num(embedding_matrix)

print(f'{not_found} words not found.')
# Out:
# 49 words not found.

# %%
model = Sequential()

model.add(Embedding(input_dim=len(word_idx)+1,output_dim=100,weights=[embedding_matrix],trainable=False))

model.add(Bidirectional(LSTM(64,return_sequences=False,dropout=0.2,recurrent_dropout=0.2)))

# model.add(Bidirectional(LSTM(64,return_sequences=False,dropout=0.3,recurrent_dropout=0.1)))

model.add(Dense(64,activation='relu'))

model.add(Dense(32,activation='relu'))

model.add(Dense(16,activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

x = np.array(training_dict['X_train'])
y = np.array(training_dict['y_train']).astype(np.float32)


u = np.array(training_dict['X_valid'])
v = np.array(training_dict['y_valid']).astype(np.float32)

# model = load_model('./models/model1')

u =     pad_sequences(u,padding="post")
x =     pad_sequences(x,padding="post")

print(x.shape,y.shape,u.shape,v.shape)

history = model.fit(x, y, epochs = 100, batch_size = 64, 
        validation_data = (u,v),
        verbose = 1)

model.save('model1')

model.evaluate(x,y,batch_size=64)
model.evaluate(u,v,batch_size=64)
# Out:
# 2022-05-13 12:40:41.218394: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-13 12:40:41.218418: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-13 12:40:41.218435: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (predator): /proc/driver/nvidia/version does not exist
# 2022-05-13 12:40:41.218623: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (621, 73) (621,) (69, 33) (69,)
# Epoch 1/100
# 10/10 [==============================] - 5s 116ms/step - loss: 0.6925 - accuracy: 0.5169 - val_loss: 0.6973 - val_accuracy: 0.4348
# Epoch 2/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.6896 - accuracy: 0.5443 - val_loss: 0.7163 - val_accuracy: 0.2029
# Epoch 3/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.6864 - accuracy: 0.5700 - val_loss: 0.6997 - val_accuracy: 0.4058
# Epoch 4/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6908 - accuracy: 0.5137 - val_loss: 0.7449 - val_accuracy: 0.1449
# Epoch 5/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.6830 - accuracy: 0.5636 - val_loss: 0.7233 - val_accuracy: 0.3043
# Epoch 6/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.6776 - accuracy: 0.5749 - val_loss: 0.6955 - val_accuracy: 0.5362
# Epoch 7/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.6700 - accuracy: 0.5862 - val_loss: 0.7761 - val_accuracy: 0.2899
# Epoch 8/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6608 - accuracy: 0.6248 - val_loss: 0.7018 - val_accuracy: 0.6232
# Epoch 9/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.6627 - accuracy: 0.5942 - val_loss: 0.8392 - val_accuracy: 0.3623
# Epoch 10/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.6602 - accuracy: 0.6023 - val_loss: 0.8013 - val_accuracy: 0.4638
# Epoch 11/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6465 - accuracy: 0.6361 - val_loss: 0.7562 - val_accuracy: 0.5217
# Epoch 12/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.6400 - accuracy: 0.6361 - val_loss: 0.6571 - val_accuracy: 0.6812
# Epoch 13/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.6310 - accuracy: 0.6345 - val_loss: 0.8058 - val_accuracy: 0.4928
# Epoch 14/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.6297 - accuracy: 0.6345 - val_loss: 0.9778 - val_accuracy: 0.3188
# Epoch 15/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.6290 - accuracy: 0.6135 - val_loss: 0.9021 - val_accuracy: 0.3913
# Epoch 16/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.6121 - accuracy: 0.6602 - val_loss: 0.7957 - val_accuracy: 0.5797
# Epoch 17/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.5842 - accuracy: 0.6812 - val_loss: 0.8735 - val_accuracy: 0.5217
# Epoch 18/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.5878 - accuracy: 0.6892 - val_loss: 0.9341 - val_accuracy: 0.4783
# Epoch 19/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.5754 - accuracy: 0.7053 - val_loss: 0.9868 - val_accuracy: 0.4058
# Epoch 20/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.5789 - accuracy: 0.6908 - val_loss: 1.2686 - val_accuracy: 0.2754
# Epoch 21/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.5797 - accuracy: 0.7021 - val_loss: 0.9809 - val_accuracy: 0.4493
# Epoch 22/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.5528 - accuracy: 0.7359 - val_loss: 0.7954 - val_accuracy: 0.5652
# Epoch 23/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.5264 - accuracy: 0.7279 - val_loss: 0.9398 - val_accuracy: 0.5072
# Epoch 24/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.5146 - accuracy: 0.7552 - val_loss: 0.8115 - val_accuracy: 0.6667
# Epoch 25/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.5362 - accuracy: 0.7279 - val_loss: 0.9011 - val_accuracy: 0.4928
# Epoch 26/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.5293 - accuracy: 0.7407 - val_loss: 1.1345 - val_accuracy: 0.4058
# Epoch 27/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.5185 - accuracy: 0.7617 - val_loss: 1.0383 - val_accuracy: 0.3913
# Epoch 28/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.4539 - accuracy: 0.7971 - val_loss: 1.0840 - val_accuracy: 0.5072
# Epoch 29/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.4693 - accuracy: 0.7939 - val_loss: 0.8939 - val_accuracy: 0.5797
# Epoch 30/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.4595 - accuracy: 0.7939 - val_loss: 0.9975 - val_accuracy: 0.5362
# Epoch 31/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4289 - accuracy: 0.8132 - val_loss: 0.9705 - val_accuracy: 0.5217
# Epoch 32/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.4585 - accuracy: 0.7987 - val_loss: 1.3053 - val_accuracy: 0.3768
# Epoch 33/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.4528 - accuracy: 0.7939 - val_loss: 1.1144 - val_accuracy: 0.3768
# Epoch 34/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4172 - accuracy: 0.8229 - val_loss: 1.3686 - val_accuracy: 0.4638
# Epoch 35/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3946 - accuracy: 0.8277 - val_loss: 1.6983 - val_accuracy: 0.3043
# Epoch 36/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.3819 - accuracy: 0.8325 - val_loss: 1.9876 - val_accuracy: 0.2174
# Epoch 37/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3860 - accuracy: 0.8213 - val_loss: 1.4253 - val_accuracy: 0.4348
# Epoch 38/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.3473 - accuracy: 0.8567 - val_loss: 1.3110 - val_accuracy: 0.4348
# Epoch 39/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.3661 - accuracy: 0.8486 - val_loss: 1.7400 - val_accuracy: 0.3913
# Epoch 40/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3403 - accuracy: 0.8583 - val_loss: 1.6851 - val_accuracy: 0.4058
# Epoch 41/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.3358 - accuracy: 0.8647 - val_loss: 2.0682 - val_accuracy: 0.3623
# Epoch 42/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.3242 - accuracy: 0.8744 - val_loss: 2.0679 - val_accuracy: 0.4493
# Epoch 43/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3328 - accuracy: 0.8663 - val_loss: 2.5106 - val_accuracy: 0.3333
# Epoch 44/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3042 - accuracy: 0.8808 - val_loss: 1.9986 - val_accuracy: 0.4783
# Epoch 45/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.2863 - accuracy: 0.8808 - val_loss: 1.9966 - val_accuracy: 0.3913
# Epoch 46/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.2641 - accuracy: 0.8937 - val_loss: 2.1466 - val_accuracy: 0.4348
# Epoch 47/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.2676 - accuracy: 0.9002 - val_loss: 2.2104 - val_accuracy: 0.3188
# Epoch 48/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.2481 - accuracy: 0.9034 - val_loss: 2.3959 - val_accuracy: 0.3768
# Epoch 49/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.2531 - accuracy: 0.8824 - val_loss: 1.9901 - val_accuracy: 0.4348
# Epoch 50/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2610 - accuracy: 0.8969 - val_loss: 1.8671 - val_accuracy: 0.3623
# Epoch 51/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2369 - accuracy: 0.9114 - val_loss: 2.3565 - val_accuracy: 0.3333
# Epoch 52/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.2441 - accuracy: 0.8969 - val_loss: 1.7395 - val_accuracy: 0.4783
# Epoch 53/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.2342 - accuracy: 0.9195 - val_loss: 1.6460 - val_accuracy: 0.5652
# Epoch 54/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1919 - accuracy: 0.9243 - val_loss: 2.0955 - val_accuracy: 0.5072
# Epoch 55/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1665 - accuracy: 0.9195 - val_loss: 3.1668 - val_accuracy: 0.3188
# Epoch 56/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.1719 - accuracy: 0.9259 - val_loss: 2.7295 - val_accuracy: 0.3043
# Epoch 57/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1712 - accuracy: 0.9356 - val_loss: 2.3850 - val_accuracy: 0.4783
# Epoch 58/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.1925 - accuracy: 0.9388 - val_loss: 2.4664 - val_accuracy: 0.4783
# Epoch 59/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1599 - accuracy: 0.9388 - val_loss: 2.4149 - val_accuracy: 0.4203
# Epoch 60/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1734 - accuracy: 0.9420 - val_loss: 2.4035 - val_accuracy: 0.3913
# Epoch 61/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1900 - accuracy: 0.9340 - val_loss: 2.3876 - val_accuracy: 0.3913
# Epoch 62/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.1238 - accuracy: 0.9630 - val_loss: 2.7725 - val_accuracy: 0.3913
# Epoch 63/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1698 - accuracy: 0.9452 - val_loss: 2.8824 - val_accuracy: 0.3913
# Epoch 64/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.1226 - accuracy: 0.9581 - val_loss: 2.7075 - val_accuracy: 0.4058
# Epoch 65/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0962 - accuracy: 0.9710 - val_loss: 2.6734 - val_accuracy: 0.4348
# Epoch 66/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1248 - accuracy: 0.9517 - val_loss: 2.8790 - val_accuracy: 0.4203
# Epoch 67/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1556 - accuracy: 0.9452 - val_loss: 2.7565 - val_accuracy: 0.4203
# Epoch 68/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1818 - accuracy: 0.9308 - val_loss: 2.2677 - val_accuracy: 0.4203
# Epoch 69/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.1382 - accuracy: 0.9420 - val_loss: 2.5455 - val_accuracy: 0.4638
# Epoch 70/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.1026 - accuracy: 0.9678 - val_loss: 2.5450 - val_accuracy: 0.4928
# Epoch 71/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.0927 - accuracy: 0.9614 - val_loss: 2.4711 - val_accuracy: 0.4493
# Epoch 72/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0756 - accuracy: 0.9807 - val_loss: 2.9047 - val_accuracy: 0.4348
# Epoch 73/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.0932 - accuracy: 0.9694 - val_loss: 3.4455 - val_accuracy: 0.3623
# Epoch 74/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.1194 - accuracy: 0.9565 - val_loss: 3.1053 - val_accuracy: 0.4058
# Epoch 75/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1349 - accuracy: 0.9533 - val_loss: 3.3594 - val_accuracy: 0.4348
# Epoch 76/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0996 - accuracy: 0.9662 - val_loss: 3.7527 - val_accuracy: 0.3478
# Epoch 77/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.1379 - accuracy: 0.9533 - val_loss: 2.7764 - val_accuracy: 0.3478
# Epoch 78/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.1374 - accuracy: 0.9565 - val_loss: 2.6451 - val_accuracy: 0.4348
# Epoch 79/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1151 - accuracy: 0.9517 - val_loss: 3.5868 - val_accuracy: 0.3478
# Epoch 80/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.1065 - accuracy: 0.9614 - val_loss: 2.2686 - val_accuracy: 0.5362
# Epoch 81/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0813 - accuracy: 0.9823 - val_loss: 2.1873 - val_accuracy: 0.6377
# Epoch 82/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0848 - accuracy: 0.9694 - val_loss: 2.3223 - val_accuracy: 0.6377
# Epoch 83/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0850 - accuracy: 0.9742 - val_loss: 2.5022 - val_accuracy: 0.5652
# Epoch 84/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0752 - accuracy: 0.9758 - val_loss: 2.7030 - val_accuracy: 0.5362
# Epoch 85/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.1168 - accuracy: 0.9630 - val_loss: 2.1779 - val_accuracy: 0.6087
# Epoch 86/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0877 - accuracy: 0.9742 - val_loss: 2.4371 - val_accuracy: 0.5362
# Epoch 87/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0834 - accuracy: 0.9710 - val_loss: 2.9116 - val_accuracy: 0.5797
# Epoch 88/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1108 - accuracy: 0.9662 - val_loss: 2.1726 - val_accuracy: 0.6377
# Epoch 89/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0763 - accuracy: 0.9742 - val_loss: 3.1419 - val_accuracy: 0.4928
# Epoch 90/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0863 - accuracy: 0.9726 - val_loss: 2.6252 - val_accuracy: 0.5652
# Epoch 91/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0798 - accuracy: 0.9742 - val_loss: 2.7976 - val_accuracy: 0.5362
# Epoch 92/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0803 - accuracy: 0.9758 - val_loss: 2.8472 - val_accuracy: 0.5362
# Epoch 93/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.1102 - accuracy: 0.9694 - val_loss: 3.4643 - val_accuracy: 0.3913
# Epoch 94/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.1364 - accuracy: 0.9565 - val_loss: 2.8882 - val_accuracy: 0.4638
# Epoch 95/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0700 - accuracy: 0.9807 - val_loss: 3.0837 - val_accuracy: 0.4058
# Epoch 96/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0573 - accuracy: 0.9839 - val_loss: 2.8221 - val_accuracy: 0.5072
# Epoch 97/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0497 - accuracy: 0.9839 - val_loss: 3.6408 - val_accuracy: 0.3913
# Epoch 98/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0514 - accuracy: 0.9791 - val_loss: 3.5297 - val_accuracy: 0.4058
# Epoch 99/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0518 - accuracy: 0.9823 - val_loss: 3.2740 - val_accuracy: 0.4928
# Epoch 100/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0530 - accuracy: 0.9919 - val_loss: 3.3223 - val_accuracy: 0.4493
# 2022-05-13 12:42:07.023452: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f22c0718dc0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f223abf7d00> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 10/10 [==============================] - 1s 29ms/step - loss: 0.0031 - accuracy: 1.0000
# 2/2 [==============================] - 0s 14ms/step - loss: 3.3223 - accuracy: 0.4493
# [3.322317361831665, 0.4492753744125366]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from IPython.display import Image
model_name = 'model1'
model_dir = './models/'

plot_model(model, to_file=f'{model_dir}{model_name}.png', show_shapes=True)

Image(f'{model_dir}{model_name}.png')

# %%
str = ['']

tokenizer = Tokenizer(lower=lower, filters=filters)
tokenizer.fit_on_texts(str)

tx = tokenizer.texts_to_sequences(str)
print(tx)
print(model.predict(tx)[0])
# Out:
# [[]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32845/1954656629.py in <module>
#       6 tx = tokenizer.texts_to_sequences(str)
#       7 print(tx)
# ----> 8 print(model.predict(tx)[0])
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     244     inputs = pack_x_y_sample_weight(x, y, sample_weights)
#     245
# --> 246     num_samples = set(int(i.shape[0]) for i in tf.nest.flatten(inputs)).pop()
#     247     _check_data_cardinality(inputs)
#     248
#
# KeyError: 'pop from an empty set'
